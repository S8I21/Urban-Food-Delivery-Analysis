# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('urban_food_delivery_messy.csv')

# %%
df_raw = df.copy()

# %%
df = df_raw.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   Order_Date             2570 non-null   object
#  4   City                   2550 non-null   object
#  5   Cuisine_Type           2551 non-null   object
#  6   Platform               2550 non-null   object
#  7   Payment_Mode           2436 non-null   object
#  8   Weather_Condition      2413 non-null   object
#  9   Order_Status           2570 non-null   object
#  10  Order_Amount_INR       2570 non-null   object
#  11  Delivery_Fee_INR       2570 non-null   float64
#  12  Discount_Applied_INR   2266 non-null   float64
#  13  Customer_Rating        2322 non-null   float64
# ...

# %%
df = df.drop(columns = ['_temp_flag','Unnamed: 21', 'Unnamed: 22'],errors = 'ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   Order_Date             2570 non-null   object
#  4   City                   2550 non-null   object
#  5   Cuisine_Type           2551 non-null   object
#  6   Platform               2550 non-null   object
#  7   Payment_Mode           2436 non-null   object
#  8   Weather_Condition      2413 non-null   object
#  9   Order_Status           2570 non-null   object
#  10  Order_Amount_INR       2570 non-null   object
#  11  Delivery_Fee_INR       2570 non-null   float64
#  12  Discount_Applied_INR   2266 non-null   float64
#  13  Customer_Rating        2322 non-null   float64
# ...

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'],infer_datetime_format=True,errors = 'coerce')
df['Order_Date_Only'] = df['Order_Date'].dt.date
df['Order_Time_Only'] = df['Order_Date'].dt.time
# Out:
# /tmp/ipykernel_7422/3554350554.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'],infer_datetime_format=True,errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   Order_Date             2370 non-null   datetime64[ns]
#  4   City                   2550 non-null   object
#  5   Cuisine_Type           2551 non-null   object
#  6   Platform               2550 non-null   object
#  7   Payment_Mode           2436 non-null   object
#  8   Weather_Condition      2413 non-null   object
#  9   Order_Status           2570 non-null   object
#  10  Order_Amount_INR       2570 non-null   object
#  11  Delivery_Fee_INR       2570 non-null   float64
#  12  Discount_Applied_INR   2266 non-null   float64
#  13  Customer_Rating        2322 non-null   float64
# ...

# %%
df = df.drop(columns = ['Order_Date'],errors = 'ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2550 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   object
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2401 non-null   object
# ...

# %%
df.head(1)
# Out:
#     Order_ID Customer_ID Restaurant_ID       City Cuisine_Type Platform  \
# 0  ORD332518    CUST2313       REST826  Bangaluru    Fast Food   Zomato
#
#   Payment_Mode Weather_Condition    Order_Status Order_Amount_INR  ...  \
# 0         Cash             Windy  Partial Refund          2042.28  ...
#
#    Discount_Applied_INR  Customer_Rating  Delivery_Time_Minutes Distance_KM  \
# 0                177.28              1.2                     52         NaN
#
#    Items_Ordered  Customer_Age  Restaurant_Avg_Rating  Is_Repeat_Customer  \
# 0              7          50.0                    3.6                   1
#
#    Order_Date_Only Order_Time_Only
# 0       2022-08-15        16:23:35
#
# [1 rows x 21 columns]

# %%
df['Order_Date_Only'] = pd.to_datetime(df['Order_Date_Only'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2550 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   object
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2401 non-null   object
# ...

# %%
cleaned_strings = df['Order_Amount_INR'].astype(str).str.replace(r'[^\d.]', '', regex=True)

df['Order_Amount_INR'] = pd.to_numeric(cleaned_strings, errors='coerce')

# %%
df.head(25)
# Out:
#      Order_ID Customer_ID Restaurant_ID       City  Cuisine_Type    Platform  \
# 0   ORD332518    CUST2313       REST826  Bangaluru     Fast Food      Zomato
# 1   ORD169326    CUST2998       REST279  Bangalore   Street Food      Zomato
# 2   ORD489043    CUST6490       REST596    Kolkata       Chinese      Swiggy
# 3   ORD952679    CUST4144       REST414     Mumbai   Continental  Direct App
# 4   ORD192295    CUST7977       REST723    Chennai   Continental      Swiggy
# 5   ORD313068    CUST2314       REST437  Ahmedabad   Street Food      Zomato
# 6   ORD979789    CUST9701       REST504    Kolkata       Chinese  Direct App
# 7   ORD371306    CUST4387      REST881#    Kolkata       Biryani    MagicPin
# 8   ORD224473    CUST6500       REST277  Bangalore  South Indian      Swiggy
# 9   ORD780364    CUST4769       REST748  Hyderabad  North Indian  Direct App
# 10  ORD160426    CUST4565       REST472     Mumbai       Biryani    MagicPin
# ...

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#     Order_ID Customer_ID Restaurant_ID       City Cuisine_Type    Platform  \
# 0  ORD332518    CUST2313       REST826  Bangaluru    Fast Food      Zomato
# 1  ORD169326    CUST2998       REST279  Bangalore  Street Food      Zomato
# 2  ORD489043    CUST6490       REST596    Kolkata      Chinese      Swiggy
# 3  ORD952679    CUST4144       REST414     Mumbai  Continental  Direct App
# 4  ORD192295    CUST7977       REST723    Chennai  Continental      Swiggy
#
#   Payment_Mode Weather_Condition    Order_Status  Order_Amount_INR  ...  \
# 0         Cash             Windy  Partial Refund           2042.28  ...
# 1          NaN            Cloudy        Returned            714.92  ...
# 2        u.p.i             Windy       Cancelled           1544.04  ...
# 3          UPI             Rainy       Delivered           2136.33  ...
# 4       Wallet               NaN  Partial Refund            476.10  ...
#
#    Discount_Applied_INR  Customer_Rating  Delivery_Time_Minutes Distance_KM  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2551 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2551 non-null   object
#  1   Customer_ID            2551 non-null   object
#  2   Restaurant_ID          2551 non-null   object
#  3   City                   2531 non-null   object
#  4   Cuisine_Type           2532 non-null   object
#  5   Platform               2531 non-null   object
#  6   Payment_Mode           2417 non-null   object
#  7   Weather_Condition      2397 non-null   object
#  8   Order_Status           2551 non-null   object
#  9   Order_Amount_INR       2551 non-null   float64
#  10  Delivery_Fee_INR       2551 non-null   float64
#  11  Discount_Applied_INR   2251 non-null   float64
#  12  Customer_Rating        2304 non-null   float64
#  13  Delivery_Time_Minutes  2383 non-null   object
# ...

# %%
df['City'].value_counts()
# Out:
# City
# Kolkata      334
# Hyderabad    326
# Pune         304
# Ahmedabad    293
# Delhi        263
# Bangalore    241
# Mumbai       222
# Chennai      221
# chennai       24
# Bangaluru     20
# delhi         19
# DELHI         18
# CHENNAI       17
# Madras        16
# new delhi     16
# mumbai        16
# New Delhi     16
# Chenai        16
# BANGALORE     16
# bangalore     15
# Mumbai        15
# BLR           15
# Bengaluru     14
# MUMBAI        14
# mUMBAI        13
# Delh1         11
#  Mumbai       11
# DELHI          9
# Mumabi         6
# UNKNOWN        4
# unknown        2
# ?              2
# --             2
# Name: count, dtype: int64

# %%
import numpy as np

# %%
df['City'] = df['City'].replace(['unknown','Unknown','UNKNOWN','?','--'],np.nan)

# %%
df['City'].value_counts()
# Out:
# City
# Kolkata      334
# Hyderabad    326
# Pune         304
# Ahmedabad    293
# Delhi        263
# Bangalore    241
# Mumbai       222
# Chennai      221
# chennai       24
# Bangaluru     20
# delhi         19
# DELHI         18
# CHENNAI       17
# BANGALORE     16
# Madras        16
# New Delhi     16
# new delhi     16
# mumbai        16
# Chenai        16
# bangalore     15
# BLR           15
# Mumbai        15
# MUMBAI        14
# Bengaluru     14
# mUMBAI        13
#  Mumbai       11
# Delh1         11
# DELHI          9
# Mumabi         6
# Name: count, dtype: int64

# %%
df['City'] = df['City'].replace(['mUMBAI','MUMBAI','Mumabi','mumbai',' Mumbai','Mumbai '],'Mumbai')

# %%
df = df_raw.copy()

# %%
df['City'].value_counts()
# Out:
# City
# Kolkata      335
# Hyderabad    327
# Pune         306
# Ahmedabad    299
# Delhi        264
# Bangalore    243
# Chennai      225
# Mumbai       224
# chennai       24
# Bangaluru     20
# delhi         19
# DELHI         18
# CHENNAI       17
# Madras        16
# new delhi     16
# mumbai        16
# New Delhi     16
# Chenai        16
# BANGALORE     16
# bangalore     15
# Mumbai        15
# BLR           15
# Bengaluru     14
# MUMBAI        14
# mUMBAI        13
# Delh1         11
#  Mumbai       11
# DELHI          9
# Mumabi         6
# UNKNOWN        4
# unknown        2
# ?              2
# --             2
# Name: count, dtype: int64

# %%
df['City'] = df['City'].replace(['mUMBAI','MUMBAI','Mumabi','mumbai',' Mumbai','Mumbai '],'Mumbai')

# %%
df['City'].value_counts()
# Out:
# City
# Kolkata      335
# Hyderabad    327
# Pune         306
# Ahmedabad    299
# Mumbai       299
# Delhi        264
# Bangalore    243
# Chennai      225
# chennai       24
# Bangaluru     20
# delhi         19
# DELHI         18
# CHENNAI       17
# New Delhi     16
# Madras        16
# new delhi     16
# Chenai        16
# BANGALORE     16
# BLR           15
# bangalore     15
# Bengaluru     14
# Delh1         11
# DELHI          9
# UNKNOWN        4
# unknown        2
# ?              2
# --             2
# Name: count, dtype: int64

# %%
df['City'] = df['City'].replace(['unknown','Unknown','UNKNOWN','?','--'],np.nan)

# %%
df['City'].value_counts()
# Out:
# City
# Kolkata      335
# Hyderabad    327
# Pune         306
# Ahmedabad    299
# Mumbai       299
# Delhi        264
# Bangalore    243
# Chennai      225
# chennai       24
# Bangaluru     20
# delhi         19
# DELHI         18
# CHENNAI       17
# Madras        16
# New Delhi     16
# Chenai        16
# new delhi     16
# BANGALORE     16
# bangalore     15
# BLR           15
# Bengaluru     14
# Delh1         11
# DELHI          9
# Name: count, dtype: int64

# %%
df['City'] = df['City'].replace(['new delhi','Delh1',' DELHI','DELHI ','delhi','New Delhi'],'Delhi')

# %%
df['City'].value_counts()
# Out:
# City
# Delhi        344
# Kolkata      335
# Hyderabad    327
# Pune         306
# Mumbai       299
# Ahmedabad    299
# Bangalore    243
# Chennai      225
# chennai       24
# Bangaluru     20
# CHENNAI       17
# Madras        16
# Chenai        16
# BANGALORE     16
# bangalore     15
# BLR           15
# Bengaluru     14
# DELHI          9
# Name: count, dtype: int64

# %%
df['City'] = df['City'].replace(['CHENNAI','Chenai','chennai','Madras'],'Chennai')

# %%
df['City'].value_counts()
# Out:
# City
# Delhi        344
# Kolkata      335
# Hyderabad    327
# Pune         306
# Ahmedabad    299
# Mumbai       299
# Chennai      298
# Bangalore    243
# Bangaluru     20
# BANGALORE     16
# bangalore     15
# BLR           15
# Bengaluru     14
# DELHI          9
# Name: count, dtype: int64

# %%
df['City'] = df['City'].replace(['Bangaluru','bangalore','Bengaluru','BANGALORE','BLR'],'Bangalore')

# %%
df['City'].value_counts()
# Out:
# City
# Delhi        344
# Kolkata      335
# Hyderabad    327
# Bangalore    323
# Pune         306
# Mumbai       299
# Ahmedabad    299
# Chennai      298
# DELHI          9
# Name: count, dtype: int64

# %%
df_V1 = df.copy() # the checkpoint

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   Order_Date             2570 non-null   object
#  4   City                   2540 non-null   object
#  5   Cuisine_Type           2551 non-null   object
#  6   Platform               2550 non-null   object
#  7   Payment_Mode           2436 non-null   object
#  8   Weather_Condition      2413 non-null   object
#  9   Order_Status           2570 non-null   object
#  10  Order_Amount_INR       2570 non-null   object
#  11  Delivery_Fee_INR       2570 non-null   float64
#  12  Discount_Applied_INR   2266 non-null   float64
#  13  Customer_Rating        2322 non-null   float64
# ...

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'],infer_datetime_format=True,errors = 'coerce')
df['Order_Date_Only'] = df['Order_Date'].dt.date
df['Order_Time_Only'] = df['Order_Date'].dt.time
# Out:
# /tmp/ipykernel_7422/3554350554.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'],infer_datetime_format=True,errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   Order_Date             2370 non-null   datetime64[ns]
#  4   City                   2540 non-null   object
#  5   Cuisine_Type           2551 non-null   object
#  6   Platform               2550 non-null   object
#  7   Payment_Mode           2436 non-null   object
#  8   Weather_Condition      2413 non-null   object
#  9   Order_Status           2570 non-null   object
#  10  Order_Amount_INR       2570 non-null   object
#  11  Delivery_Fee_INR       2570 non-null   float64
#  12  Discount_Applied_INR   2266 non-null   float64
#  13  Customer_Rating        2322 non-null   float64
# ...

# %%
df = df.drop(columns = ['Order_Date','_temp_flag','Unnamed: 21','Unnamed: 22'],errors = 'ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   object
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2401 non-null   object
# ...

# %%
df['Order_Date_Only'] = pd.to_datetime(df['Order_Date_Only'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   object
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2401 non-null   object
# ...

# %%
cleaned_string = df['Order_Amount_INR'].astype(str).str.replace(r'[^\d.]', '', regex=True)
df['Order_Amount_INR'] = pd.to_numeric(cleaned_string, errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2401 non-null   object
# ...

# %%
df_V2 = df.copy()

# %%
df_V2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2401 non-null   object
# ...

# %%
df.drop_duplicates()
# Out:
#        Order_ID Customer_ID Restaurant_ID       City Cuisine_Type    Platform  \
# 0     ORD332518    CUST2313       REST826  Bangalore    Fast Food      Zomato
# 1     ORD169326    CUST2998       REST279  Bangalore  Street Food      Zomato
# 2     ORD489043    CUST6490       REST596    Kolkata      Chinese      Swiggy
# 3     ORD952679    CUST4144       REST414     Mumbai  Continental  Direct App
# 4     ORD192295    CUST7977       REST723    Chennai  Continental      Swiggy
# ...         ...         ...           ...        ...          ...         ...
# 2565  ORD655550    CUST6772       REST123  Hyderabad      Mughlai      Swiggy
# 2566  ORD963994    CUST8903       REST724  Ahmedabad      Biryani      Swiggy
# 2567  ORD490532    CUST4004       REST329       Pune    Fast Food      Swiggy
# 2568  ORD970708    CUST6984       REST479    Kolkata      Italian  Direct App
# 2569  ORD898462    CUST9066       REST146     Mumbai      Chinese      Swiggy
#
# ...

# %%
df_v3 = df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2401 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2401 non-null   object
# ...

# %%
df['Items_Ordered']
# Out:
# 0       7
# 1       9
# 2       8
# 3       3
# 4       1
#        ..
# 2565    5
# 2566    3
# 2567    4
# 2568    6
# 2569    2
# Name: Items_Ordered, Length: 2570, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2401 non-null   object
# ...

# %%
df['Delivery_Time_Minutes'] = pd.to_numeric(df['Delivery_Time_Minutes'],errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2376 non-null   float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2376 non-null   float64
# ...

# %%
df['Payment_Mode'].head(500)
# Out:
# 0            Cash
# 1             NaN
# 2           u.p.i
# 3             UPI
# 4          Wallet
#           ...
# 495        Wallet
# 496    Debit Card
# 497          Cash
# 498    Debit Card
# 499          Cash
# Name: Payment_Mode, Length: 500, dtype: object

# %%
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Wallet              500
# Debit Card          469
# Cash                454
# UPI                 428
# Credit Card         406
# Cash on Delivery     18
# UPI                  17
# cash                 17
# u.p.i                16
# Upi                  16
# Credit_Card          16
# CASH                 14
# COD                  14
# CreditCard           14
# CC                   13
# credit card          13
# upi                  11
# Name: count, dtype: int64

# %%
df['Payment_Mode'] = df['Payment_Mode'].replace(['UPI ',' UPI','u.p.i','upi','Upi'],'UPI')

# %%
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Wallet              500
# UPI                 488
# Debit Card          469
# Cash                454
# Credit Card         406
# Cash on Delivery     18
# cash                 17
# Credit_Card          16
# CASH                 14
# CreditCard           14
# COD                  14
# CC                   13
# credit card          13
# Name: count, dtype: int64

# %%
df['Payment_Mode'] = df['Payment_Mode'].replace(['CreditCard','Credit_Card','credit card','CC'],'Credit Card')

# %%
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Wallet              500
# UPI                 488
# Debit Card          469
# Credit Card         462
# Cash                454
# Cash on Delivery     18
# cash                 17
# CASH                 14
# COD                  14
# Name: count, dtype: int64

# %%
df['Payment_Mode'] = df['Payment_Mode'].replace(['cash','CASH'],'Cash')

# %%
df['Payment_Mode'] = df['Payment_Mode'].replace(['Cash on Delivery', 'Cash on Delievery'], 'Cash')

# %%
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Cash           503
# Wallet         500
# UPI            488
# Debit Card     469
# Credit Card    462
# COD             14
# Name: count, dtype: int64

# %%
df_V4 = df.copy()

# %%
df_V4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2551 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2376 non-null   float64
# ...

# %%
df_V4.head()
# Out:
#     Order_ID Customer_ID Restaurant_ID       City Cuisine_Type    Platform  \
# 0  ORD332518    CUST2313       REST826  Bangalore    Fast Food      Zomato
# 1  ORD169326    CUST2998       REST279  Bangalore  Street Food      Zomato
# 2  ORD489043    CUST6490       REST596    Kolkata      Chinese      Swiggy
# 3  ORD952679    CUST4144       REST414     Mumbai  Continental  Direct App
# 4  ORD192295    CUST7977       REST723    Chennai  Continental      Swiggy
#
#   Payment_Mode Weather_Condition    Order_Status  Order_Amount_INR  ...  \
# 0         Cash             Windy  Partial Refund           2042.28  ...
# 1          NaN            Cloudy        Returned            714.92  ...
# 2          UPI             Windy       Cancelled           1544.04  ...
# 3          UPI             Rainy       Delivered           2136.33  ...
# 4       Wallet               NaN  Partial Refund            476.10  ...
#
#    Discount_Applied_INR  Customer_Rating  Delivery_Time_Minutes  Distance_KM  \
# ...

# %%
df.iloc[0:5].T
# Out:
#                                          0                    1  \
# Order_ID                         ORD332518            ORD169326
# Customer_ID                       CUST2313             CUST2998
# Restaurant_ID                      REST826              REST279
# City                             Bangalore            Bangalore
# Cuisine_Type                     Fast Food          Street Food
# Platform                            Zomato               Zomato
# Payment_Mode                          Cash                  NaN
# Weather_Condition                    Windy               Cloudy
# Order_Status                Partial Refund             Returned
# Order_Amount_INR                   2042.28               714.92
# Delivery_Fee_INR                     68.24                17.65
# Discount_Applied_INR                177.28                 83.2
# Customer_Rating                        1.2                  3.6
# Delivery_Time_Minutes                 52.0                113.0
# ...

# %%
df['Order_Date_Only'] = df['Order_Date_Only'].dt.date

# %%
df.iloc[50:100].T
# Out:
#                                50           51           52          53  \
# Order_ID                ORD278795    ORD949376    ORD875584   ORD741055
# Customer_ID              CUST6966     CUST8942     CUST9851    CUST4181
# Restaurant_ID             REST223      REST653      REST669     REST901
# City                      Chennai    Hyderabad    Ahmedabad     Kolkata
# Cuisine_Type              Italian  Street Food  Street Food   Fast Food
# Platform                 MagicPin        DotPe     MagicPin  Direct App
# Payment_Mode                  UPI   Debit Card          UPI        Cash
# Weather_Condition           Rainy       Cloudy        Rainy       Rainy
# Order_Status             Returned    Cancelled     Returned   Cancelled
# Order_Amount_INR          2192.84      1343.62         87.6     1540.48
# Delivery_Fee_INR             16.9        28.94        33.95       64.19
# Discount_Applied_INR       154.97       167.38       238.62      208.64
# ...

# %%
df['Cuisine_Type'].value_counts()
# Out:
# Cuisine_Type
# Biryani             268
# Fast Food           262
# Continental         262
# Mughlai             256
# Italian             251
# Desserts            249
# South Indian        245
# Chinese             237
# Street Food         236
# North Indian        234
#   Chinese            10
#   Street Food         9
#   Continental         5
# UNKNOWN               4
#   Italian             4
# unknown               4
#   South Indian        2
#   Desserts            2
#   Biryani             2
#   Fast Food           2
# --                    2
#   North Indian        2
#   Mughlai             2
# ?                     1
# Name: count, dtype: int64

# %%
df['Cuisine_Type'] = df['Cuisine_Type'].replace(['--','?'],np.nan)

# %%
df['Cuisine_Type'].value_counts()
# Out:
# Cuisine_Type
# Biryani             268
# Fast Food           262
# Continental         262
# Mughlai             256
# Italian             251
# Desserts            249
# South Indian        245
# Chinese             237
# Street Food         236
# North Indian        234
#   Chinese            10
#   Street Food         9
#   Continental         5
# unknown               4
# UNKNOWN               4
#   Italian             4
#   South Indian        2
#   Desserts            2
#   Biryani             2
#   Fast Food           2
#   North Indian        2
#   Mughlai             2
# Name: count, dtype: int64

# %%
df['Cusinie_Type'] = df['Cuisine_Type'].replace(['UNKOWN','unknown'],'UNKNOWN')

# %%
df_V5 = df.copy()

# %%
df['Cuisine_Type']  = df['Cuisine_Type'].replace(['unknown','UNKNOWN'],'Unknown')

# %%
df['Cuisine_Type'].value_counts()
# Out:
# Cuisine_Type
# Biryani             268
# Fast Food           262
# Continental         262
# Mughlai             256
# Italian             251
# Desserts            249
# South Indian        245
# Chinese             237
# Street Food         236
# North Indian        234
#   Chinese            10
#   Street Food         9
# Unknown               8
#   Continental         5
#   Italian             4
#   South Indian        2
#   Desserts            2
#   Biryani             2
#   Fast Food           2
#   North Indian        2
#   Mughlai             2
# Name: count, dtype: int64

# %%
df['Cuisine_Type'] = df['Cuisine_Type'].str.strip() # remeber whenever white space problem do this.

# %%
df['Cuisine_Type'].value_counts()
# Out:
# Cuisine_Type
# Biryani         270
# Continental     267
# Fast Food       264
# Mughlai         258
# Italian         255
# Desserts        251
# Chinese         247
# South Indian    247
# Street Food     245
# North Indian    236
# Unknown           8
# Name: count, dtype: int64

# %%
df_V7 = df.copy()

# %%
df_V7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2548 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2376 non-null   float64
# ...

# %%
#now checking for the null values:
df.isnull().sum()
# Out:
# Order_ID                   0
# Customer_ID                0
# Restaurant_ID              0
# City                      30
# Cuisine_Type              22
# Platform                  20
# Payment_Mode             134
# Weather_Condition        157
# Order_Status               0
# Order_Amount_INR           0
# Delivery_Fee_INR           0
# Discount_Applied_INR     304
# Customer_Rating          248
# Delivery_Time_Minutes    194
# Distance_KM              237
# Items_Ordered              0
# Customer_Age             128
# Restaurant_Avg_Rating      0
# Is_Repeat_Customer         0
# Order_Date_Only          200
# Order_Time_Only          200
# Cusinie_Type              22
# dtype: int64

# %%
df_V7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2548 non-null   object
#  5   Platform               2550 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2376 non-null   float64
# ...

# %%
df.iloc[0:5].T
# Out:
#                                     0            1           2            3  \
# Order_ID                    ORD332518    ORD169326   ORD489043    ORD952679
# Customer_ID                  CUST2313     CUST2998    CUST6490     CUST4144
# Restaurant_ID                 REST826      REST279     REST596      REST414
# City                        Bangalore    Bangalore     Kolkata       Mumbai
# Cuisine_Type                Fast Food  Street Food     Chinese  Continental
# Platform                       Zomato       Zomato      Swiggy   Direct App
# Payment_Mode                     Cash          NaN         UPI          UPI
# Weather_Condition               Windy       Cloudy       Windy        Rainy
# Order_Status           Partial Refund     Returned   Cancelled    Delivered
# Order_Amount_INR              2042.28       714.92     1544.04      2136.33
# Delivery_Fee_INR                68.24        17.65       56.85        71.55
# ...

# %%
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Cash           503
# Wallet         500
# UPI            488
# Debit Card     469
# Credit Card    462
# COD             14
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# Delhi        344
# Kolkata      335
# Hyderabad    327
# Bangalore    323
# Pune         306
# Mumbai       299
# Ahmedabad    299
# Chennai      298
# DELHI          9
# Name: count, dtype: int64

# %%
df['City'] = df['City'].replace(['DELHI'],'Delhi')

# %%
df['City'].value_counts()
# Out:
# City
# Delhi        353
# Kolkata      335
# Hyderabad    327
# Bangalore    323
# Pune         306
# Mumbai       299
# Ahmedabad    299
# Chennai      298
# Name: count, dtype: int64

# %%
df['Cuisine_Type'].value_counts()
# Out:
# Cuisine_Type
# Biryani         270
# Continental     267
# Fast Food       264
# Mughlai         258
# Italian         255
# Desserts        251
# Chinese         247
# South Indian    247
# Street Food     245
# North Indian    236
# Unknown           8
# Name: count, dtype: int64

# %%
df['Platform'] = df['Platform'].replace(['unknown','UNKNOWN'],'Unknown')

# %%
df['Platform'].value_counts()
# Out:
# Platform
# Swiggy        536
# MagicPin      530
# Zomato        498
# DotPe         490
# Direct App    486
# Unknown         7
# ?               2
# --              1
# Name: count, dtype: int64

# %%
df['Platform'] = df['Platform'].replace(['?','--'],np.nan)

# %%
df['Platform'].value_counts()
# Out:
# Platform
# Swiggy        536
# MagicPin      530
# Zomato        498
# DotPe         490
# Direct App    486
# Unknown         7
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2548 non-null   object
#  5   Platform               2547 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2376 non-null   float64
# ...

# %%
df.drop(columns=['Cusinie_Type'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2548 non-null   object
#  5   Platform               2547 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2376 non-null   float64
# ...

# %%
df['Distance_KM'].value_counts()
# Out:
# Distance_KM
# 4.17     8
# 13.97    7
# 4.06     6
# 5.68     6
# 10.70    6
#         ..
# 7.38     1
# 3.41     1
# 12.25    1
# 10.55    1
# 12.14    1
# Name: count, Length: 1145, dtype: int64

# %%
df['Order_Date_Only'].isnull().sum()
# Out:
# np.int64(200)

# %%
df['Order_Date_Only'].isnull().sum()
# Out:
# np.int64(200)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2570 non-null   object
#  1   Customer_ID            2570 non-null   object
#  2   Restaurant_ID          2570 non-null   object
#  3   City                   2540 non-null   object
#  4   Cuisine_Type           2548 non-null   object
#  5   Platform               2547 non-null   object
#  6   Payment_Mode           2436 non-null   object
#  7   Weather_Condition      2413 non-null   object
#  8   Order_Status           2570 non-null   object
#  9   Order_Amount_INR       2570 non-null   float64
#  10  Delivery_Fee_INR       2570 non-null   float64
#  11  Discount_Applied_INR   2266 non-null   float64
#  12  Customer_Rating        2322 non-null   float64
#  13  Delivery_Time_Minutes  2376 non-null   float64
# ...

# %%
#Filling of the null fields i.e. mean median and mode so in order to do that here are the categories:

# %%
#Mean: Data is normally distributed — no extreme outliers pulling the average up or down
#e.g. Customer_Age, Height, Temperature,
#Median: Data is skewed — outliers exist that would distort the mean
#e.g. Salary, Order_Amount, Distance_KM, Ratings
#Mode: Column is categorical — fill with most frequent category
#e.g. City, Platform, Weather_Condition, Payment_Mode

# %%
df['Weather_Condition'] = df['Weather_Condition'].fillna(df['Weather_Condition'].mode()[0])

# %%
df['Payment_Mode'] = df['Payment_Mode'].fillna(df['Payment_Mode'].mode()[0])

# %%
df['Platform'] = df['Platform'].fillna(df['Platform'].mode()[0])

# %%
df['Cuisine_Type'] = df['Cuisine_Type'].fillna(df['Cuisine_Type'].mode()[0])

# %%
print(df.isnull().sum())
# Out:
# Order_ID                   0
# Customer_ID                0
# Restaurant_ID              0
# City                      30
# Cuisine_Type               0
# Platform                   0
# Payment_Mode               0
# Weather_Condition          0
# Order_Status               0
# Order_Amount_INR           0
# Delivery_Fee_INR           0
# Discount_Applied_INR     304
# Customer_Rating          248
# Delivery_Time_Minutes    194
# Distance_KM              237
# Items_Ordered              0
# Customer_Age             128
# Restaurant_Avg_Rating      0
# Is_Repeat_Customer         0
# Order_Date_Only          200
# Order_Time_Only          200
# dtype: int64

# %%
#Numerical
num_cols = ['Discount_Applied_INR','Customer_Rating','Distance_KM','Delivery_Time_Minutes','Customer_Age']
for col in num_cols:
  df[col] = df[col].fillna(df[col].median())

# %%
print(df.isnull().sum())
# Out:
# Order_ID                   0
# Customer_ID                0
# Restaurant_ID              0
# City                      30
# Cuisine_Type               0
# Platform                   0
# Payment_Mode               0
# Weather_Condition          0
# Order_Status               0
# Order_Amount_INR           0
# Delivery_Fee_INR           0
# Discount_Applied_INR       0
# Customer_Rating            0
# Delivery_Time_Minutes      0
# Distance_KM                0
# Items_Ordered              0
# Customer_Age               0
# Restaurant_Avg_Rating      0
# Is_Repeat_Customer         0
# Order_Date_Only          200
# Order_Time_Only          200
# dtype: int64

# %%
df.dropna(subset = ['City'], inplace = True)
df.reset_index(drop = True,inplace = True)

# %%
print(df.isnull().sum())
print(df.shape)
# Out:
# Order_ID                   0
# Customer_ID                0
# Restaurant_ID              0
# City                       0
# Cuisine_Type               0
# Platform                   0
# Payment_Mode               0
# Weather_Condition          0
# Order_Status               0
# Order_Amount_INR           0
# Delivery_Fee_INR           0
# Discount_Applied_INR       0
# Customer_Rating            0
# Delivery_Time_Minutes      0
# Distance_KM                0
# Items_Ordered              0
# Customer_Age               0
# Restaurant_Avg_Rating      0
# Is_Repeat_Customer         0
# Order_Date_Only          198
# Order_Time_Only          198
# dtype: int64
# (2540, 21)

# %%
df['Customer_Rating'].value_counts()
# Out:
# Customer_Rating
#  3.2     310
#  3.7      78
#  4.9      73
#  4.2      69
#  3.1      68
#  3.8      66
#  4.6      66
#  1.1      64
#  5.0      63
#  2.6      63
#  3.4      60
#  2.3      59
#  4.1      59
#  3.6      58
#  2.9      58
#  2.8      58
#  1.2      57
#  3.3      56
#  3.9      55
#  4.8      55
#  3.5      55
#  2.7      55
#  2.4      55
#  1.3      54
#  3.0      53
#  4.4      53
#  2.0      53
#  4.0      53
#  4.7      52
#  4.3      52
#  1.6      52
#  2.5      50
#  1.5      49
#  1.8      49
#  4.5      47
#  1.7      45
#  1.4      45
#  1.9      45
#  2.2      45
#  2.1      37
#  1.0      31
#  6.0       6
#  99.0      5
#  0.0       2
#  10.0      1
# -1.0       1
# Name: count, dtype: int64

# %%
df.dropna(subset = ['Order_Date_Only'], inplace = True)

# %%
df.isnull().sum()
# Out:
# Order_ID                 0
# Customer_ID              0
# Restaurant_ID            0
# City                     0
# Cuisine_Type             0
# Platform                 0
# Payment_Mode             0
# Weather_Condition        0
# Order_Status             0
# Order_Amount_INR         0
# Delivery_Fee_INR         0
# Discount_Applied_INR     0
# Customer_Rating          0
# Delivery_Time_Minutes    0
# Distance_KM              0
# Items_Ordered            0
# Customer_Age             0
# Restaurant_Avg_Rating    0
# Is_Repeat_Customer       0
# Order_Date_Only          0
# Order_Time_Only          0
# dtype: int64

# %%
mask = df['Discount_Applied_INR'] > df['Order_Amount_INR']
print(f"Number of rows where discount_applied_INR is greater than the Order_Amount_INR: {mask.sum()} ") #f basically is formatted string literals that helps to change the literals inside using curly braces
# Out:
# Number of rows where discount_applied_INR is greater than the Order_Amount_INR: 104

# %%
df = df[df['Discount_Applied_INR'] > df['Order_Amount_INR']]
df.reset_index(drop = True, inplace = True)
print(df.shape)
# Out:
# (104, 21)

# %%
mask = df['Discount_Applied_INR'] > df['Order_Amount_INR']
print(f"Number of rows where discount_applied_INR is greater than the Order_Amount_INR: {mask.sum()} ")
# Out:
# Number of rows where discount_applied_INR is greater than the Order_Amount_INR: 104

# %%
df = df[df['Discount_Applied_INR'] <= df['Order_Amount_INR']].reset_index(drop=True)
print(df.shape)
# Out:
# (0, 21)

# %%
print(df.columns.tolist())
print(df[['Discount_Applied_INR', 'Order_Amount_INR']].head())
# Out:
# ['Order_ID', 'Customer_ID', 'Restaurant_ID', 'City', 'Cuisine_Type', 'Platform', 'Payment_Mode', 'Weather_Condition', 'Order_Status', 'Order_Amount_INR', 'Delivery_Fee_INR', 'Discount_Applied_INR', 'Customer_Rating', 'Delivery_Time_Minutes', 'Distance_KM', 'Items_Ordered', 'Customer_Age', 'Restaurant_Avg_Rating', 'Is_Repeat_Customer', 'Order_Date_Only', 'Order_Time_Only']
# Empty DataFrame
# Columns: [Discount_Applied_INR, Order_Amount_INR]
# Index: []

# %%
#this is the most toughest part of finding out such rows that provide order_amount not greater to INR. So we will upload the clear data now.

# %%
df = pd.read_csv('urban_food_delivery_cleaned.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2370 entries, 0 to 2369
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2370 non-null   object
#  1   Customer_ID            2370 non-null   object
#  2   Restaurant_ID          2370 non-null   object
#  3   City                   2342 non-null   object
#  4   Cuisine_Type           2349 non-null   object
#  5   Platform               2348 non-null   object
#  6   Payment_Mode           2240 non-null   object
#  7   Weather_Condition      2226 non-null   object
#  8   Order_Status           2370 non-null   object
#  9   Order_Amount_INR       2370 non-null   float64
#  10  Delivery_Fee_INR       2370 non-null   float64
#  11  Discount_Applied_INR   2088 non-null   float64
#  12  Customer_Rating        2136 non-null   float64
#  13  Delivery_Time_Minutes  2192 non-null   float64
# ...

# %%
df['Weather_Condition'] = df['Weather_Condition'].fillna(df['Weather_Condition'].mode()[0])
df['Payment_Mode'] = df['Payment_Mode'].fillna(df['Payment_Mode'].mode()[0])
df['Platform'] = df['Platform'].fillna(df['Platform'].mode()[0])
df['Cuisine_Type'] = df['Cuisine_Type'].fillna('Unknown')

# %%
num_cols = ['Discount_Applied_INR','Customer_Rating','Distance_KM','Delivery_Time_Minutes']
for col in num_cols:
  df[col] = df[col].fillna(df[col].median())
df['Customer_Age'] = df['Customer_Age'].fillna(df['Customer_Age'].mean())

df.dropna(subset = ['Order_Date_Only'], inplace = True)
df.dropna(subset=['City'],inplace = True)
df.reset_index(drop = True,inplace = True)

df = df[df['Discount_Applied_INR'] <= df['Order_Amount_INR']].reset_index(drop = True)
print (df.shape)
# Out:
# (2238, 21)

# %%
df = df[df['Discount_Applied_INR'] <= df['Order_Amount_INR']].reset_index(drop=True)

print(df.shape)
print(df.isnull().sum())
# Out:
# (2238, 21)
# Order_ID                 0
# Customer_ID              0
# Restaurant_ID            0
# City                     0
# Cuisine_Type             0
# Platform                 0
# Payment_Mode             0
# Weather_Condition        0
# Order_Status             0
# Order_Amount_INR         0
# Delivery_Fee_INR         0
# Discount_Applied_INR     0
# Customer_Rating          0
# Delivery_Time_Minutes    0
# Distance_KM              0
# Items_Ordered            0
# Customer_Age             0
# Restaurant_Avg_Rating    0
# Is_Repeat_Customer       0
# Order_Date_Only          0
# Order_Time_Only          0
# dtype: int64

# %%
print (df.shape)
# Out:
# (2238, 21)

# %%
#Outlier
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2238 non-null   object
#  1   Customer_ID            2238 non-null   object
#  2   Restaurant_ID          2238 non-null   object
#  3   City                   2238 non-null   object
#  4   Cuisine_Type           2238 non-null   object
#  5   Platform               2238 non-null   object
#  6   Payment_Mode           2238 non-null   object
#  7   Weather_Condition      2238 non-null   object
#  8   Order_Status           2238 non-null   object
#  9   Order_Amount_INR       2238 non-null   float64
#  10  Delivery_Fee_INR       2238 non-null   float64
#  11  Discount_Applied_INR   2238 non-null   float64
#  12  Customer_Rating        2238 non-null   float64
#  13  Delivery_Time_Minutes  2238 non-null   float64
# ...

# %%
df.iloc[11:20].T
# Out:
#                                    11            12          13          14  \
# Order_ID                    ORD813013     ORD921609   ORD750318   ORD717413
# Customer_ID                  CUST6136      CUST9276    CUST3019    CUST4715
# Restaurant_ID                 REST943       REST267     REST809     REST702
# City                          Chennai        Mumbai   Ahmedabad       Delhi
# Cuisine_Type                  Mughlai  South Indian     Italian    Desserts
# Platform                     Magicpin        Zomato      Swiggy      Swiggy
# Payment_Mode               Debit Card          Cash      Wallet  Debit Card
# Weather_Condition               Rainy         Sunny       Sunny       Sunny
# Order_Status           Partial Refund     Delivered   Cancelled    Returned
# Order_Amount_INR               127.85        411.43      436.95     1397.01
# Delivery_Fee_INR                36.68         21.06       51.17       25.56
# ...

# %%
Q1 = df['Order_Amount_INR'].quantile(0.25)
Q3 = df['Order_Amount_INR'].quantile(0.75)
IQR = Q3-Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
print(f"Lower: {lower},Upper: {upper}")
outliers = df[(df['Order_Amount_INR'] < lower) | (df['Order_Amount_INR'] > upper)]
print(f"Outliers: {len(outliers)}")
# Out:
# Lower: -1056.2337500000003,Upper: 3697.3162500000008
# Outliers: 7

# %%
Q1= df['Delivery_Fee_INR'].quantile(0.25)
Q3 = df['Delivery_Fee_INR'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
print(f"Lower: {lower}, Upper: {upper}")
outliers = df[(df['Delivery_Fee_INR'] < lower) | (df['Delivery_Fee_INR'] > upper)]
print(f"Outliers: {len(outliers)}")
# Out:
# Lower: -40.515, Upper: 119.285
# Outliers: 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2238 non-null   object
#  1   Customer_ID            2238 non-null   object
#  2   Restaurant_ID          2238 non-null   object
#  3   City                   2238 non-null   object
#  4   Cuisine_Type           2238 non-null   object
#  5   Platform               2238 non-null   object
#  6   Payment_Mode           2238 non-null   object
#  7   Weather_Condition      2238 non-null   object
#  8   Order_Status           2238 non-null   object
#  9   Order_Amount_INR       2238 non-null   float64
#  10  Delivery_Fee_INR       2238 non-null   float64
#  11  Discount_Applied_INR   2238 non-null   float64
#  12  Customer_Rating        2238 non-null   float64
#  13  Delivery_Time_Minutes  2238 non-null   float64
# ...

# %%
#standard pandas use to extract from the database [] but we want the list of the field too so in order to do that you need to have
#another bracket
cols = df[['Delivery_Fee_INR','Order_Amount_INR', 'Delivery_Time_Minutes', 'Distance_KM','Customer_Age']]
#this way it will take them as fetching from dataframe, and look them as a one single key of the dictionary
#cols = df('Delivery_Time_Minutes','Order_Amount_INR','Delivery_Time_Minutes','Distace_KM','Customer_Age')
for col in cols:
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3-Q1
  lower = Q1 - 1.5*IQR
  upper =Q3 + 1.5*IQR
  outliers = df[(df[col]<lower) | (df[col]>upper)]
  print(f"{col} -> Outliers: {len(outliers)},Lower: {lower:.2f},Upper: {upper: .2f}")
# Out:
# Delivery_Fee_INR -> Outliers: 0,Lower: -40.52,Upper:  119.28
# Order_Amount_INR -> Outliers: 7,Lower: -1056.23,Upper:  3697.32
# Delivery_Time_Minutes -> Outliers: 8,Lower: -37.50,Upper:  166.50
# Distance_KM -> Outliers: 8,Lower: -5.31,Upper:  20.64
# Customer_Age -> Outliers: 0,Lower: -1.00,Upper:  87.00

# %%
#keep good rows where value <= upper
#drop rows where value > upper
df = df[df['Order_Amount_INR'] <= 3697.32]
df = df[df['Distance_KM'] <= 20.64]
df = df[df['Delivery_Time_Minutes'] <= 166.50]

# %%
print(df.shape)
print(df[['Order_Amount_INR','Distance_KM','Delivery_Time_Minutes']].describe())
# Out:
# (2215, 21)
#        Order_Amount_INR  Distance_KM  Delivery_Time_Minutes
# count       2215.000000  2215.000000            2215.000000
# mean        1314.933223     7.693720              64.889842
# std          681.553696     3.973673              31.491106
# min           85.280000    -2.000000              -5.000000
# 25%          726.535000     4.420000              39.000000
# 50%         1317.550000     7.670000              65.000000
# 75%         1913.470000    10.870000              90.000000
# max         2499.570000    14.990000             120.000000

# %%
df = df[df['Distance_KM'] >= 0]
df = df[df['Delivery_Time_Minutes'] >= 0]

# %%
print(df[['Order_Amount_INR','Distance_KM','Delivery_Time_Minutes']].describe())
# Out:
#        Order_Amount_INR  Distance_KM  Delivery_Time_Minutes
# count       2209.000000  2209.000000            2209.000000
# mean        1315.178452     7.703105              64.982345
# std          681.400789     3.968208              31.370061
# min           85.280000     0.000000               0.000000
# 25%          726.160000     4.420000              39.000000
# 50%         1318.800000     7.670000              65.000000
# 75%         1913.320000    10.880000              90.000000
# max         2499.570000    14.990000             120.000000

# %%
df.to_csv('urban_food_delivery_final_clean.csv', index = False)
from google.colab import files #we wrote false in the above index because pandas will impose the false of their line
files.download('urban_food_delivery_final_clean.csv')

# %%
#Exploratory Data Analysis begans:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('urban_food_delivery_final_clean.csv')
print(df.shape)
print(df.head())
# Out:
# (2209, 21)
#     Order_ID Customer_ID Restaurant_ID       City Cuisine_Type    Platform  \
# 0  ORD332518    CUST2313       REST826  Bangalore    Fast Food      Zomato
# 1  ORD169326    CUST2998       REST279  Bangalore  Street Food      Zomato
# 2  ORD489043    CUST6490       REST596    Kolkata      Chinese      Swiggy
# 3  ORD952679    CUST4144       REST414     Mumbai  Continental  Direct App
# 4  ORD192295    CUST7977       REST723    Chennai  Continental      Swiggy
#
#   Payment_Mode Weather_Condition    Order_Status  Order_Amount_INR  ...  \
# 0         Cash             Windy  Partial Refund           2042.28  ...
# 1       Wallet            Cloudy        Returned            714.92  ...
# 2          UPI             Windy       Cancelled           1544.04  ...
# 3          UPI             Rainy       Delivered           2136.33  ...
# 4       Wallet             Sunny  Partial Refund            476.10  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2209 entries, 0 to 2208
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2209 non-null   object
#  1   Customer_ID            2209 non-null   object
#  2   Restaurant_ID          2209 non-null   object
#  3   City                   2209 non-null   object
#  4   Cuisine_Type           2209 non-null   object
#  5   Platform               2209 non-null   object
#  6   Payment_Mode           2209 non-null   object
#  7   Weather_Condition      2209 non-null   object
#  8   Order_Status           2209 non-null   object
#  9   Order_Amount_INR       2209 non-null   float64
#  10  Delivery_Fee_INR       2209 non-null   float64
#  11  Discount_Applied_INR   2209 non-null   float64
#  12  Customer_Rating        2209 non-null   float64
#  13  Delivery_Time_Minutes  2209 non-null   float64
# ...

# %%
cities_count = df['City'].value_counts()

# %%
#Matploblib
x = cities_count.index
y = cities_count.values
plt.figure(figsize = (10,5))
plt.bar(x,y)
plt.title('Analysis of the order by the Cities')
plt.xlabel('Cities')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
cuisine_count = df['Cuisine_Type'].value_counts()
x = cuisine_count.index
y = cuisine_count.values

# %%
plt.figure(figsize = (10,5))
plt.bar(x,y,color = 'coral')
plt.title('Types of Cuisine')
plt.xlabel('Cuisine_Type')
plt.xticks(rotation=45, ha='right')
plt.ylabel('counts')

plt.show()

# %%
plt.tight_layout()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2209 entries, 0 to 2208
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2209 non-null   object
#  1   Customer_ID            2209 non-null   object
#  2   Restaurant_ID          2209 non-null   object
#  3   City                   2209 non-null   object
#  4   Cuisine_Type           2209 non-null   object
#  5   Platform               2209 non-null   object
#  6   Payment_Mode           2209 non-null   object
#  7   Weather_Condition      2209 non-null   object
#  8   Order_Status           2209 non-null   object
#  9   Order_Amount_INR       2209 non-null   float64
#  10  Delivery_Fee_INR       2209 non-null   float64
#  11  Discount_Applied_INR   2209 non-null   float64
#  12  Customer_Rating        2209 non-null   float64
#  13  Delivery_Time_Minutes  2209 non-null   float64
# ...

# %%
platform_count = df['Platform'].value_counts()
x = platform_count.index
y = platform_count.values
plt.figure(figsize=(10,5))
plt.bar(x,y,color = 'Yellow')
plt.xlabel('Different platform')
plt.ylabel('counts')
plt.xticks(rotation = 45, ha = 'right')

plt.show()

# %%
payment_counts = df['Payment_Mode'].value_counts()
x = payment_counts.index
y = payment_counts.values
plt.figure(figsize=(10,5))
plt.bar(x,y,color = 'Blue')
plt.xlabel('Different platform')
plt.ylabel('counts')
plt.xticks(rotation = 45,ha ='right')
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Wallet'),
#   Text(1, 0, 'Cash'),
#   Text(2, 0, 'UPI'),
#   Text(3, 0, 'Debit Card'),
#   Text(4, 0, 'Credit Card'),
#   Text(5, 0, 'COD')])

# %%
plt.hist(df['Customer_Age'], bins = 10, color = 'coral')
# Out:
# (array([202., 192., 193., 173., 224., 358., 192., 225., 230., 220.]),
#  array([18. , 22.7, 27.4, 32.1, 36.8, 41.5, 46.2, 50.9, 55.6, 60.3, 65. ]),
#  <BarContainer object of 10 artists>)

# %%
bins = [18,25,35,45,55,100]
labels = ['18-25','26-35','36-45','45-55','55+']
df['Age_Group'] = pd.cut(df['Customer_Age'], bins = bins,labels = labels)
age_group_counts = df['Age_Group'].value_counts().sort_index()
x = age_group_counts.index
y = age_group_counts.values
plt.figure(figsize=(10,5))
plt.xlabel('Different Age-Groups')
plt.ylabel('Total_count according to age')
plt.bar(x, y, color='coral')
plt.title('Order Count by Age Group')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2209 entries, 0 to 2208
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2209 non-null   object
#  1   Customer_ID            2209 non-null   object
#  2   Restaurant_ID          2209 non-null   object
#  3   City                   2209 non-null   object
#  4   Cuisine_Type           2209 non-null   object
#  5   Platform               2209 non-null   object
#  6   Payment_Mode           2209 non-null   object
#  7   Weather_Condition      2209 non-null   object
#  8   Order_Status           2209 non-null   object
#  9   Order_Amount_INR       2209 non-null   float64
#  10  Delivery_Fee_INR       2209 non-null   float64
#  11  Discount_Applied_INR   2209 non-null   float64
#  12  Customer_Rating        2209 non-null   float64
#  13  Delivery_Time_Minutes  2209 non-null   float64
# ...

# %%
weather_count = df['Weather_Condition'].value_counts()
x = weather_count.index
y = weather_count.values
plt.figure(figsize=(10,5))
plt.xlabel('Weather')
plt.ylabel('Orders accoding to weather')
plt.bar(x, y, color='Black')
plt.title('Order Count by Weather condition')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.figure(figsize=(10,5))

# %%
order_status = df['Order_Status'].value_counts()
x = order_status.index
y = order_status.values

plt.figure(figsize=(8,8))
plt.pie(y,labels = x,autopct = '%1.1f%%',colors = ['#4ECDC4','#FF6B68','#45B7D1','#FFEAA7','#DDA0DD'])
plt.title('Order Status Breakdown')
plt.tight_layout()
plt.show()

# %%
#Now begin the group by checking the orders of the shops and values
city_avg_order = df.groupby('City')['Order_Amount_INR'].mean()

# %%
x = city_avg_order.index
y = city_avg_order.values

# %%
plt.figure(figsize=(10,5))
plt.ylabel('Cities')
plt.xlabel('Orders accoding to cities')
plt.barh(x, y, color='steelblue')
plt.title('Order Average Count by cities')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.figure(figsize=(10,5))

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Restaurant_ID', 'City', 'Cuisine_Type',
#        'Platform', 'Payment_Mode', 'Weather_Condition', 'Order_Status',
#        'Order_Amount_INR', 'Delivery_Fee_INR', 'Discount_Applied_INR',
#        'Customer_Rating', 'Delivery_Time_Minutes', 'Distance_KM',
#        'Items_Ordered', 'Customer_Age', 'Restaurant_Avg_Rating',
#        'Is_Repeat_Customer', 'Order_Date_Only', 'Order_Time_Only',
#        'Age_Group'],
#       dtype='object')

# %%
plt.figure(figsize = (8,6))
sns.boxplot(x= 'Is_Repeat_Customer', y= 'Order_Amount_INR',data = df)
plt.title('Spending: Repeat vs New Customers')
plt.xlabel('Consistency of Customers')
plt.ylabel('Total_Amount')
# Out:
# Text(0, 0.5, 'Total_Amount')

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Restaurant_ID', 'City', 'Cuisine_Type',
#        'Platform', 'Payment_Mode', 'Weather_Condition', 'Order_Status',
#        'Order_Amount_INR', 'Delivery_Fee_INR', 'Discount_Applied_INR',
#        'Customer_Rating', 'Delivery_Time_Minutes', 'Distance_KM',
#        'Items_Ordered', 'Customer_Age', 'Restaurant_Avg_Rating',
#        'Is_Repeat_Customer', 'Order_Date_Only', 'Order_Time_Only',
#        'Age_Group'],
#       dtype='object')

# %%
x = df['Distance_KM']
y =df['Delivery_Time_Minutes']

# %%
plt.figure(figsize=(10,6))
plt.scatter(x, y, color='coral', alpha=0.5)
plt.title('Distance vs Delivery Time')
plt.xlabel('Distance (KM)')
plt.ylabel('Delivery Time (Minutes)')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.heatmap(df.select_dtypes(include = 'number').corr(),annot=True,fmt='.2f',cmap='coolwarm') #corr is the relation that needs to be carry out
plt.title('Correalation Heatmap')
plt.show()

# %%
# !pip install duckdb
